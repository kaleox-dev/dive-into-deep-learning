# %%
# exercises

# %%
# 1. pass
# 2. pass
# 3. pass
# 4. d/dx (x^x) = x^x + x^x * ln(x)
# 5. extrema/flat spot
# 6. pass
# 7. gradient: <6x_1, 5e^{x_2}>
# 8. there is no gradient because it is not differentable. there is a sharp edge at x = 0
# 9. 
# 10.
