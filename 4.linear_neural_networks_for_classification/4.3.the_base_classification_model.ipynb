# %%
import torch
from d2l import torch as d2l

# %%
class Classifier(d2l.Module):  #@save
    """The base class of classification models."""
    def validation_step(self, batch):
        Y_hat = self(*batch[:-1])
        self.plot('loss', self.loss(Y_hat, batch[-1]), train=False)
        self.plot('acc', self.accuracy(Y_hat, batch[-1]), train=False)

# %%
@d2l.add_to_class(d2l.Module)  #@save
def configure_optimizers(self):
    return torch.optim.SGD(self.parameters(), lr=self.lr)

# %%
@d2l.add_to_class(Classifier)  #@save
def accuracy(self, Y_hat, Y, averaged=True):
    """Compute the number of correct predictions."""
    Y_hat = Y_hat.reshape((-1, Y_hat.shape[-1]))
    preds = Y_hat.argmax(axis=1).type(Y.dtype)
    compare = (preds == Y.reshape(-1)).type(torch.float32)
    return compare.mean() if averaged else compare

# %%
# summary
# assess accuracy by making vector with 1 for true, 0 for false and summing for # of correct preds

# %%
"""
exercises
1. context:
L_v is the true validation loss
L_v^q is computed by averaging the loss over only a subset of the validation data, rather than full validation set
l_v^b is the loss on the last minibatch
N: validation set size
B: minibatch size
M = N/B: total minibatches

this is not deterministic! find an unbiased estimator

L_v = B/N * l_v^b + (B-N)/N * L_v^q

2. 

3. 
"""
